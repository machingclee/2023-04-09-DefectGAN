# %%
import os, re

# %%
head_num_regex = re.compile(r"^\d+")
seg_dir = "toy_subsets/water_seepage_segmentation"
for filename in os.listdir(seg_dir):
  try:
    src = filename
    rename = re.sub("task-", "", src)
    rename = re.sub("-annotation.*\.png", "", rename)
    rename = rename.zfill(5) + ".png"
    os.rename(os.path.join(seg_dir, src), os.path.join(seg_dir, rename))
  except Exception as err:
    os.unlink(os.path.join(seg_dir, src))
    print("ignore err")

# %%
crack_dir = "toy_subsets/cracks"
fir i, filename in os.listdir(crack_dir):
  j = i+1
  print("rename to ", os.path.join(crack_dir, str(j).zfill(5) + ".png")
  # os.rename(os.path.join(crack_dir, filename), os.path.join(crack_dir, str(j).zfill(5) + ".png"))
# Out:
# ['defect_00025.png',
#  'defect_00026.png',
#  'defect_00027.png',
#  'defect_00178.png',
#  'defect_00179.png',
#  'defect_00180.png',
#  'defect_00203.png',
#  'defect_00434.png',
#  'defect_00435.png',
#  'defect_00436.png',
#  'defect_00437.png',
#  'defect_00438.png',
#  'defect_00439.png',
#  'defect_00440.png',
#  'defect_00658.png',
#  'defect_00659.png',
#  'defect_00660.png',
#  'defect_00661.png',
#  'defect_00664.png',
#  'defect_00665.png',
#  'defect_00669.png',
#  'defect_00670.png',
#  'defect_00680.png',
#  'defect_00787.png',
#  'defect_00788.png',
#  'defect_00789.png',
#  'defect_00790.png',
#  'defect_00793.png',
#  'defect_00794.png',
#  'defect_00795.png',
#  'defect_00796.png',
#  'defect_00801.png',
#  'defect_00802.png',
#  'defect_00803.png',
#  'defect_00804.png',
#  'defect_00828.png',
#  'defect_00838.png',
#  'defect_00839.png',
#  'defect_00840.png',
#  'defect_00841.png',
#  'defect_00842.png',
#  'defect_00843.png',
#  'defect_00851.png',
#  'defect_00852.png',
#  'defect_00853.png',
#  'defect_00855.png',
#  'defect_00860.png',
#  'defect_00861.png',
#  'defect_00862.png',
#  'defect_00891.png',
#  'defect_00902.png',
#  'defect_00903.png',
#  'defect_00904.png',
#  'defect_00932.png',
#  'defect_00933.png',
#  'defect_00934.png',
#  'defect_00935.png',
#  'defect_00936.png',
#  'defect_00954.png',
#  'defect_00955.png',
#  'defect_00958.png',
#  'defect_00959.png',
#  'defect_00990.png',
#  'defect_01797.png',
#  'defect_01829.png',
#  'defect_01895.png',
#  'defect_01896.png',
#  'defect_01904.png',
#  'defect_01905.png',
#  'defect_01942.png',
#  'defect_01943.png',
#  'defect_01944.png',
#  'defect_01945.png',
#  'defect_01947.png',
#  'defect_01948.png',
#  'defect_01969.png',
#  'defect_02012.png',
#  'defect_02015.png',
#  'defect_02254.png',
#  'defect_02403.png',
#  'defect_02406.png',
#  'defect_02407.png',
#  'defect_02408.png',
#  'defect_02517.png',
#  'defect_02518.png',
#  'defect_02519.png',
#  'defect_02520.png',
#  'defect_02521.png',
#  'defect_02522.png',
#  'defect_02523.png',
#  'defect_02524.png',
#  'defect_02525.png',
#  'defect_02539.png',
#  'defect_02541.png',
#  'defect_02542.png',
#  'defect_02543.png',
#  'defect_02544.png',
#  'defect_02581.png',
#  'defect_02582.png',
#  'defect_02585.png',
#  'defect_02588.png',
#  'defect_02589.png',
#  'defect_02609.png',
#  'defect_02980.png',
#  'defect_02981.png',
#  'defect_02982.png',
#  'defect_02986.png',
#  'defect_02989.png',
#  'defect_02999.png',
#  'defect_03025.png',
#  'defect_03083.png',
#  'defect_03084.png',
#  'defect_03116.png',
#  'defect_03117.png',
#  'defect_03120.png',
#  'defect_03123.png',
#  'defect_03124.png',
#  'defect_03125.png',
#  'defect_03128.png',
#  'defect_03140.png',
#  'defect_03141.png',
#  'defect_03143.png',
#  'defect_03144.png',
#  'defect_03146.png',
#  'defect_03147.png',
#  'defect_03151.png',
#  'defect_03152.png',
#  'defect_03155.png',
#  'defect_03156.png',
#  'defect_03157.png',
#  'defect_03158.png',
#  'defect_03169.png',
#  'defect_03173.png',
#  'defect_03249.png',
#  'defect_03289.png',
#  'defect_03306.png',
#  'defect_03307.png',
#  'defect_03308.png',
#  'defect_03309.png',
#  'defect_03321.png',
#  'defect_03366.png',
#  'defect_03370.png',
#  'defect_03372.png',
#  'defect_03373.png',
#  'defect_03393.png']
